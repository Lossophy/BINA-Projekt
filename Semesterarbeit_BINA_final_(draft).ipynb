# %% [markdown]
# <a href="https://colab.research.google.com/github/Lossophy/BINA-Projekt/blob/main/Semesterarbeit_BINA_final_(draft).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trends in der Energiebranche seit 1980

# %% [markdown]
# ## Einleitung

# %% [markdown]
# Die Schweiz konzentrierte sich vor der Erarbeitung der Energiestrategie 2050 primär auf 4 Säulen: Energieeffizienz, erneuerbare Energien, Ersatz und Neubau von Grosskraftwerken zur Stromproduktion (auch Kernkraft) und die Energieaussenpolitik. Seit der Reaktorkatastrophe von Fukushima, dem danach beschlossenen schrittweisen Ausstieg aus der Kernkraft und weiteren internationalen Veränderungen im Energieumfeld hat sich einiges getan. Im Rahmen dieser Energiestrategie 2050 wurden etwa ein neues Energiegesetz, eine Strategie für unsere Stromnetze sowie Ziele zur Reduktion unserer Treibhausgasemissionen (Stichwort «Pariser Klimaübereinkommen») konkretisiert und beschlossen.
#
# In dieser Arbeit nehmen wir die Perspektive von Mitarbeitern beim Bundesamt für Energie BFE ein. Wir sind in der Abteilung „Betriebswirtschaft und Organisation“ angestellt. In diesem Bereich wird auch das „Kompetenzzentrum für Geoinformation, Open Government Data und Digitalisierung im Energiesektor“ betrieben.

# %% [markdown]
# ## Fragestellung

# %% [markdown]
# Um die Veränderungen und Anstrengungen, die zur Umsetzung der Energiestrategie 2050 nötig sind, zu unterstützen, haben wir von unserer Abteilungsleitung eine begleitende Aufgabe erhalten:
#
# «Historische und aktuelle Informationen zur Energiewirtschaft der Schweiz einem breiteren Adressatenkreis aus Politik und Wirtschaft verständlich zugänglich und erfahrbar machen.»
#
# Da es zu den Aufgaben des BFE gehört, die Voraussetzungen und Rahmenbedingungen für eine ausreichende, krisenfeste und nachhaltige Energieversorgung der Schweiz zu schaffen, sind wir auf den Einbezug vieler Akteure und Entscheidungsträger angewiesen. Indem wir ihnen die Daten zur schweizerischen Energiewirtschaft verständlich und interaktiv aufbereiten, ermöglichen wir diesen Akteuren wiederum, ihren eigenen Adressatenkreis mit verständlichen Daten zu versorgen. Mittels interessant aufbereiteter Daten die Wirkung von Massnahmen und Ereignissen verfolgen zu können, erhöht in unseren Augen die Bereitschaft, diese mitzutragen. Für eine Energiestrategie, deren Umsetzung mehrere Jahrzehnte in Anspruch nimmt und Erfolge teilweise erst mit grosser Verzögerung spürbar werden, eine nicht unwesentliche Voraussetzung.

# %% [markdown]
# ### Zielsetzung

# %% [markdown]
# ## Methodik

# %% [markdown]
# Bei der Suche nach passenden Daten haben wir auf mehrere Faktoren geachtet und uns für die schweizerische Gesamtenergiestatistik des BFE entschieden. Daraus schauen wir uns das Kernstück in Form der Energiebilanz an. Diese jährlich aktualisierte und aggregierte Datensatz erlaubt es uns, ohne weitere Anonymisierungsmassnahmen oder Abhängigkeiten von (privaten) Datenlieferanten zu arbeiten, die uns künftig den Zugang erschweren könnten. Eine Reihe konkreter Fragestellungen und dazu passender (interaktiver) Auswertungen und Visualisierungen soll nun das Potenzial dieses Datensatzes demonstrieren. Auf diese gehen wir nun der Reihe nach ein.
#
# Zu unseren Aufgaben gehören wie erwähnt das Schaffen von Voraussetzungen für eine krisenfeste Energieversorgung der Schweiz. Die Stimmbürgerinnen und Stimmbürger in der Schweiz haben 2017 mit der Annahme des revidierten Energiegesetzes zudem einer Reduktion der Abhängigkeit von fossilen Energien aus dem Ausland zugestimmt. Um diese Reduktion zu gewährleisten, ist ein generelles Verständnis von bisherigen und aktuellen Abhängigkeiten der Schweiz in Energiefragen nötig.

# %% [markdown]
# ## Datenanalyse & Visualisierung

# %%
# !pip install -q xlrd
# !git clone https://github.com/Lossophy/BINA-Projekt.git
# !pip install panel --quiet
# !pip install jupyter_bokeh

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import ipywidgets as widgets
from IPython.display import display
import time
from IPython.display import display, clear_output
import panel as pn
pn.extension('plotly')
# Out:
# Cloning into 'BINA-Projekt'...
# remote: Enumerating objects: 198, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 198 (delta 17), reused 4 (delta 2), pack-reused 165 (from 1)
# Receiving objects: 100% (198/198), 4.82 MiB | 9.07 MiB/s, done.
# Resolving deltas: 100% (106/106), done.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 33.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 30.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
# ...

# %%
# Datei einlesen
df = pd.read_csv('/content/BINA-Projekt/Data/ogd115_gest_bilanz.csv')

# Daten überprüfen
print(df.head())
# Out:
#    Jahr           Rubrik Energietraeger        TJ
# 0  1980  Bruttoverbrauch   Elektrizität  -29450.0
# 1  1980  Bruttoverbrauch  Erdölprodukte  321250.0
# 2  1980  Bruttoverbrauch      Fernwärme       0.0
# 3  1980  Bruttoverbrauch            Gas   36280.0
# 4  1980  Bruttoverbrauch    Holzenergie   26280.0

# %% [markdown]
# ### F1: Welche importierten Energieträger haben über die Zeit an Bedeutung gewonnen
# oder verloren?

# %% [markdown]
# ### F2: Wie haben sich die Verbrauchsmuster fossiler Energieträger in verschiedenen
# Kategorien (z. B. Industrie, Haushalte, Verkehr) verändert?

# %% [markdown]
# ### F3: Wie hat sich der Anteil erneuerbarer Energien aus inländischer Produktion
# gegenüber Importen fossiler Energieträger über die Jahre verändert?

# %% [markdown]
# ## Ergebnisse

# %% [markdown]
# Mit den vorgestellten Visualisierungen möchten wir aufzeigen, welches Potenzial in den Daten der schweizerischen Gesamtenergiestatistik steckt. Durch die jährliche Erhebung ist ein stetiger Vergleich der aktuellen mit den vergangenen Werten möglich, die aufgezeigten Visualisierungen können also stetig wiederverwendet werden. Bei Bedarf ist es mit kleinen Anpassungen möglich, weitere Zielgruppen adressatengerecht anzusprechen. Dazu können etwa einzelne Werte optisch hervorgehoben und ablenkende Elemente vermieden werden.
#
# Eine verständliche visuelle Aufbereitung der Daten zur Energiewirtschaft der Schweiz stärkt unsere Möglichkeiten, Entscheidungsträger aus Politik, (Energie-)Wirtschaft sowie indirekt weitere interessierte Kreise aus der Gesamtbevölkerung für die Herausforderungen eines sich stetig wandelnden Umfeldes zu sensibilisieren. Wir sind überzeugt, dass unsere Abteilungsleitung mit den gezeigten Instrumenten einen wichtigen Baustein erhält, der dabei hilft, alle relevanten Akteure auf diese Reise zur Erreichung der Energiestrategie 2050 mitzunehmen.
