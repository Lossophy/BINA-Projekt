# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Data/ogd115_gest_bilanz.csv")

# %%
df.head (50)
# Out:
#     Jahr                                             Rubrik  \
# 0   1980                                    Bruttoverbrauch
# 1   1980                                    Bruttoverbrauch
# 2   1980                                    Bruttoverbrauch
# 3   1980                                    Bruttoverbrauch
# 4   1980                                    Bruttoverbrauch
# 5   1980                                    Bruttoverbrauch
# 6   1980                                    Bruttoverbrauch
# 7   1980                                    Bruttoverbrauch
# 8   1980                                    Bruttoverbrauch
# 9   1980                                    Bruttoverbrauch
# 10  1980                                    Bruttoverbrauch
# 11  1980  Eigenverbrauch des Energiesektors, Netzverlust...
# 12  1980  Eigenverbrauch des Energiesektors, Netzverlust...
# 13  1980  Eigenverbrauch des Energiesektors, Netzverlust...
# 14  1980  Eigenverbrauch des Energiesektors, Netzverlust...
# ...
